# %%
import numpy as np
import pandas as pd
import matplotlib as plt
data = pd.read_csv("FoodPrice_in_Turkey.csv", header=0, encoding='ISO-8859-1')
data
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
data['Place'][0]
# Out:
# 'National Average'

# %%
data.at[0, 'Place']
# Out:
# 'National Average'

# %%
data.at[0, 'Place'] = 'Saigon'
display(data)
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0               Saigon         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
data.loc[0, 'Place'] = 'Hue'
display(data)
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0                  Hue         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
data.iloc[0,0]='Hue'
display(data)
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0                  Hue         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
data.loc[-1] = ['ThanhHoa', 66, "NEM CHUA", 5, 'KG', 6, 2022, 66.1234]
data.loc[2.5] = ['DaNang', 77, "BTCTH", 5, 'KG', 6, 2022, 66.1234]
data = data.sort_index()
display(data.head(10))
# Out:
#                  Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0          ThanhHoa         66       NEM CHUA     5     KG      6  2022
#  0.0               Hue         52  Rice - Retail     5     KG      5  2013
#  1.0  National Average         52  Rice - Retail     5     KG      6  2013
#  2.0  National Average         52  Rice - Retail     5     KG     11  2013
#  2.5            DaNang         77          BTCTH     5     KG      6  2022
#  3.0  National Average         52  Rice - Retail     5     KG     12  2013
#  4.0  National Average         52  Rice - Retail     5     KG      1  2014
#  5.0  National Average         52  Rice - Retail     5     KG      2  2014
#  6.0  National Average         52  Rice - Retail     5     KG      3  2014
#  7.0  National Average         52  Rice - Retail     5     KG      5  2014
#
#         Price
# -1.0  66.1234
#  0.0   4.4920
#  1.0   4.5786
#  2.0   4.7865
#  2.5  66.1234
#  3.0   5.1337
#  4.0   5.5099
#  5.0   5.8146
#  6.0   6.0014
#  7.0   6.3202

# %%
data.loc[2.5]
# Out:
# Place           DaNang
# ProductId           77
# ProductName      BTCTH
# UmId                 5
# UmName              KG
# Month                6
# Year              2022
# Price          66.1234
# Name: 2.5, dtype: object

# %%
data.iloc[4]
# Out:
# Place           DaNang
# ProductId           77
# ProductName      BTCTH
# UmId                 5
# UmName              KG
# Month                6
# Year              2022
# Price          66.1234
# Name: 2.5, dtype: object

# %%
data.loc[0]
# Out:
# Place                    Hue
# ProductId                 52
# ProductName    Rice - Retail
# UmId                       5
# UmName                    KG
# Month                      5
# Year                    2013
# Price                  4.492
# Name: 0.0, dtype: object

# %%
data.iloc[1]
# Out:
# Place                    Hue
# ProductId                 52
# ProductName    Rice - Retail
# UmId                       5
# UmName                    KG
# Month                      5
# Year                    2013
# Price                  4.492
# Name: 0.0, dtype: object

# %%
data.loc[[2.5, 0, -1]]
# Out:
#          Place  ProductId    ProductName  UmId UmName  Month  Year    Price
#  2.5    DaNang         77          BTCTH     5     KG      6  2022  66.1234
#  0.0       Hue         52  Rice - Retail     5     KG      5  2013   4.4920
# -1.0  ThanhHoa         66       NEM CHUA     5     KG      6  2022  66.1234

# %%
data.iloc[[4, 1, 0]]
# Out:
#          Place  ProductId    ProductName  UmId UmName  Month  Year    Price
#  2.5    DaNang         77          BTCTH     5     KG      6  2022  66.1234
#  0.0       Hue         52  Rice - Retail     5     KG      5  2013   4.4920
# -1.0  ThanhHoa         66       NEM CHUA     5     KG      6  2022  66.1234

# %%
data.loc[: 2.5]
# Out:
#                  Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0          ThanhHoa         66       NEM CHUA     5     KG      6  2022
#  0.0               Hue         52  Rice - Retail     5     KG      5  2013
#  1.0  National Average         52  Rice - Retail     5     KG      6  2013
#  2.0  National Average         52  Rice - Retail     5     KG     11  2013
#  2.5            DaNang         77          BTCTH     5     KG      6  2022
#
#         Price
# -1.0  66.1234
#  0.0   4.4920
#  1.0   4.5786
#  2.0   4.7865
#  2.5  66.1234

# %%
data.iloc[0 : 5]
# Out:
#                  Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0          ThanhHoa         66       NEM CHUA     5     KG      6  2022
#  0.0               Hue         52  Rice - Retail     5     KG      5  2013
#  1.0  National Average         52  Rice - Retail     5     KG      6  2013
#  2.0  National Average         52  Rice - Retail     5     KG     11  2013
#  2.5            DaNang         77          BTCTH     5     KG      6  2022
#
#         Price
# -1.0  66.1234
#  0.0   4.4920
#  1.0   4.5786
#  2.0   4.7865
#  2.5  66.1234

# %%
data.loc[:, "ProductName"]
# Out:
# -1.0                      NEM CHUA
#  0.0                 Rice - Retail
#  1.0                 Rice - Retail
#  2.0                 Rice - Retail
#  2.5                         BTCTH
#                     ...
#  7376.0    Cocoa (powder) - Retail
#  7377.0    Cocoa (powder) - Retail
#  7378.0    Cocoa (powder) - Retail
#  7379.0    Cocoa (powder) - Retail
#  7380.0    Cocoa (powder) - Retail
# Name: ProductName, Length: 7383, dtype: object

# %%
data.iloc[:, 2]
# Out:
# -1.0                      NEM CHUA
#  0.0                 Rice - Retail
#  1.0                 Rice - Retail
#  2.0                 Rice - Retail
#  2.5                         BTCTH
#                     ...
#  7376.0    Cocoa (powder) - Retail
#  7377.0    Cocoa (powder) - Retail
#  7378.0    Cocoa (powder) - Retail
#  7379.0    Cocoa (powder) - Retail
#  7380.0    Cocoa (powder) - Retail
# Name: ProductName, Length: 7383, dtype: object

# %%
data.loc[:,["ProductName",'Place']]
# Out:
#                      ProductName             Place
# -1.0                    NEM CHUA          ThanhHoa
#  0.0               Rice - Retail               Hue
#  1.0               Rice - Retail  National Average
#  2.0               Rice - Retail  National Average
#  2.5                       BTCTH            DaNang
# ...                          ...               ...
#  7376.0  Cocoa (powder) - Retail             Izmir
#  7377.0  Cocoa (powder) - Retail             Izmir
#  7378.0  Cocoa (powder) - Retail             Izmir
#  7379.0  Cocoa (powder) - Retail             Izmir
#  7380.0  Cocoa (powder) - Retail             Izmir
#
# [7383 rows x 2 columns]

# %%
data.iloc[:,[2,0]]
# Out:
#                      ProductName             Place
# -1.0                    NEM CHUA          ThanhHoa
#  0.0               Rice - Retail               Hue
#  1.0               Rice - Retail  National Average
#  2.0               Rice - Retail  National Average
#  2.5                       BTCTH            DaNang
# ...                          ...               ...
#  7376.0  Cocoa (powder) - Retail             Izmir
#  7377.0  Cocoa (powder) - Retail             Izmir
#  7378.0  Cocoa (powder) - Retail             Izmir
#  7379.0  Cocoa (powder) - Retail             Izmir
#  7380.0  Cocoa (powder) - Retail             Izmir
#
# [7383 rows x 2 columns]

# %%
data.loc[:, 'Place': "ProductName"]
# Out:
#                     Place  ProductId              ProductName
# -1.0             ThanhHoa         66                 NEM CHUA
#  0.0                  Hue         52            Rice - Retail
#  1.0     National Average         52            Rice - Retail
#  2.0     National Average         52            Rice - Retail
#  2.5               DaNang         77                    BTCTH
# ...                   ...        ...                      ...
#  7376.0             Izmir        502  Cocoa (powder) - Retail
#  7377.0             Izmir        502  Cocoa (powder) - Retail
#  7378.0             Izmir        502  Cocoa (powder) - Retail
#  7379.0             Izmir        502  Cocoa (powder) - Retail
#  7380.0             Izmir        502  Cocoa (powder) - Retail
#
# [7383 rows x 3 columns]

# %%
data.iloc[:, 0 : 3]
# Out:
#                     Place  ProductId              ProductName
# -1.0             ThanhHoa         66                 NEM CHUA
#  0.0                  Hue         52            Rice - Retail
#  1.0     National Average         52            Rice - Retail
#  2.0     National Average         52            Rice - Retail
#  2.5               DaNang         77                    BTCTH
# ...                   ...        ...                      ...
#  7376.0             Izmir        502  Cocoa (powder) - Retail
#  7377.0             Izmir        502  Cocoa (powder) - Retail
#  7378.0             Izmir        502  Cocoa (powder) - Retail
#  7379.0             Izmir        502  Cocoa (powder) - Retail
#  7380.0             Izmir        502  Cocoa (powder) - Retail
#
# [7383 rows x 3 columns]

# %%
data.loc[0:8, 'Place': "ProductName"]
# Out:
#                 Place  ProductId    ProductName
# 0.0               Hue         52  Rice - Retail
# 1.0  National Average         52  Rice - Retail
# 2.0  National Average         52  Rice - Retail
# 2.5            DaNang         77          BTCTH
# 3.0  National Average         52  Rice - Retail
# 4.0  National Average         52  Rice - Retail
# 5.0  National Average         52  Rice - Retail
# 6.0  National Average         52  Rice - Retail
# 7.0  National Average         52  Rice - Retail
# 8.0  National Average         52  Rice - Retail

# %%
data.iloc[1:11, 0 : 3]
# Out:
#                 Place  ProductId    ProductName
# 0.0               Hue         52  Rice - Retail
# 1.0  National Average         52  Rice - Retail
# 2.0  National Average         52  Rice - Retail
# 2.5            DaNang         77          BTCTH
# 3.0  National Average         52  Rice - Retail
# 4.0  National Average         52  Rice - Retail
# 5.0  National Average         52  Rice - Retail
# 6.0  National Average         52  Rice - Retail
# 7.0  National Average         52  Rice - Retail
# 8.0  National Average         52  Rice - Retail

# %%
data.iloc[4:18, 2 : 7]
# Out:
#         ProductName  UmId UmName  Month  Year
# 2.5           BTCTH     5     KG      6  2022
# 3.0   Rice - Retail     5     KG     12  2013
# 4.0   Rice - Retail     5     KG      1  2014
# 5.0   Rice - Retail     5     KG      2  2014
# 6.0   Rice - Retail     5     KG      3  2014
# 7.0   Rice - Retail     5     KG      5  2014
# 8.0   Rice - Retail     5     KG      6  2014
# 9.0   Rice - Retail     5     KG      7  2014
# 10.0  Rice - Retail     5     KG      8  2014
# 11.0  Rice - Retail     5     KG      9  2014
# 12.0  Rice - Retail     5     KG     10  2014
# 13.0  Rice - Retail     5     KG     11  2014
# 14.0  Rice - Retail     5     KG     12  2014
# 15.0  Rice - Retail     5     KG      1  2015

# %%
data.loc[2.5:15, "ProductName": "Year"]
# Out:
#         ProductName  UmId UmName  Month  Year
# 2.5           BTCTH     5     KG      6  2022
# 3.0   Rice - Retail     5     KG     12  2013
# 4.0   Rice - Retail     5     KG      1  2014
# 5.0   Rice - Retail     5     KG      2  2014
# 6.0   Rice - Retail     5     KG      3  2014
# 7.0   Rice - Retail     5     KG      5  2014
# 8.0   Rice - Retail     5     KG      6  2014
# 9.0   Rice - Retail     5     KG      7  2014
# 10.0  Rice - Retail     5     KG      8  2014
# 11.0  Rice - Retail     5     KG      9  2014
# 12.0  Rice - Retail     5     KG     10  2014
# 13.0  Rice - Retail     5     KG     11  2014
# 14.0  Rice - Retail     5     KG     12  2014
# 15.0  Rice - Retail     5     KG      1  2015
