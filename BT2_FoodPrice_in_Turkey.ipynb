# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("FoodPrice_in_Turkey.csv", header=0, encoding='ISO-8859-1')
display(data)
data.info()
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
print('Số dòng:', data.shape[0],'và số cột:', data.shape[1])
# Out:
# Số dòng: 7381 và số cột: 8

# %%
print('Thuộc tính của', data.columns[0], 'là định danh nominal')
print('Thuộc tính của', data.columns[1], 'là định danh nominal')
print('Thuộc tính của', data.columns[2], 'là định danh nominal')
print('Thuộc tính của', data.columns[3], 'là định danh nominal')
print('Thuộc tính của', data.columns[4], 'là định danh nominal')
print('Thuộc tính của', data.columns[5], 'là định danh nominal')
print('Thuộc tính của', data.columns[6], 'là định danh nominal')
print('Thuộc tính của', data.columns[7], 'là định tính ratio')
# Out:
# Thuộc tính của Place là định danh nominal
# Thuộc tính của ProductId là định danh nominal
# Thuộc tính của ProductName là định danh nominal
# Thuộc tính của UmId là định danh nominal
# Thuộc tính của UmName là định danh nominal
# Thuộc tính của Month là định danh nominal
# Thuộc tính của Year là định danh nominal
# Thuộc tính của Price là định tính ratio

# %%
# giá trị trung bình từng loại thực phẩm
tb_sanpham = data.groupby(data.columns[2])[data.columns[7]].mean()
display(tb_sanpham)
# Out:
# ProductName
# Apples (red) - Retail                                       2.392193
# Apples - Retail                                             3.885039
# Bananas - Retail                                            8.224784
# Beans (white) - Retail                                      9.572830
# Bread (common) - Retail                                     4.463293
# Bread (pita) - Retail                                       2.404545
# Bulgur - Retail                                             3.516712
# Cabbage - Retail                                            1.723395
# Cauliflower - Retail                                        3.274868
# Cheese - Retail                                            25.522875
# Chickpeas - Retail                                         10.347860
# Cocoa (powder) - Retail                                    43.802339
# Coffee (instant) - Retail                                  43.295493
# ...
